# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:1234@localhost:5432/INSTRUCTOR

# %%
# %%sql
# SELECT *
# FROM information_schema.tables
# WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 6 rows affected.
# [('INSTRUCTOR', 'public', 'my_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('INSTRUCTOR', 'public', 'your_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('INSTRUCTOR', 'public', 'instructor', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('INSTRUCTOR', 'public', 'international_student_test_scores', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('INSTRUCTOR', 'public', 'test_score_distribution', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('INSTRUCTOR', 'public', 'chicago_socioeconomic_data', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %%sql
# SELECT *
# FROM information_schema.columns
# WHERE table_schema = 'public' AND table_name = 'chicago_socioeconomic_data'
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 9 rows affected.
# [('INSTRUCTOR', 'public', 'chicago_socioeconomic_data', 'ca', 1, None, 'YES', 'double precision', None, None, 53, 2, None, None, None, None, None, None, None, None, None, None, None, None, None, 'INSTRUCTOR', 'pg_catalog', 'float8', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('INSTRUCTOR', 'public', 'chicago_socioeconomic_data', 'community_area_name', 2, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'INSTRUCTOR', 'pg_catalog', 'text', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
# ...
