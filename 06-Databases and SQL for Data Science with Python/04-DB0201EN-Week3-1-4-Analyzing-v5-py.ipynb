# %%
from sqlalchemy import create_engine

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:1234@localhost:5432/INSTRUCTOR

# %%
import pandas
chicago_socioeconomic_data = pandas.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')
chicago_socioeconomic_data
# Out:
#       ca community_area_name  percent_of_housing_crowded  \
# 0    1.0         Rogers Park                         7.7
# 1    2.0          West Ridge                         7.8
# 2    3.0              Uptown                         3.8
# 3    4.0      Lincoln Square                         3.4
# 4    5.0        North Center                         0.3
# ..   ...                 ...                         ...
# 73  74.0     Mount Greenwood                         1.0
# 74  75.0         Morgan Park                         0.8
# 75  76.0              O'Hare                         3.6
# 76  77.0           Edgewater                         4.1
# 77   NaN             CHICAGO                         4.7
#
#     percent_households_below_poverty  percent_aged_16_unemployed  \
# 0                               23.6                         8.7
# 1                               17.2                         8.8
# 2                               24.0                         8.9
# ...

# %%
# Create SQLAlchemy engine
engine = create_engine('postgresql://postgres:1234@localhost:5432/INSTRUCTOR')

# Convert DataFrame to SQL table
chicago_socioeconomic_data.to_sql('chicago_socioeconomic_data', engine, if_exists='replace', index=False)
# Out:
# 78

# %%
chicago_socioeconomic_data = %sql SELECT * FROM test_score_distribution
chicago_socioeconomic_data
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 78 rows affected.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0),
#  (14.0, 'Albany Park', 11.3, 19.2, 10.0, 32.9, 32.0, 21323, 53.0),
# ...

# %%
# %sql SELECT count(*) FROM chicago_socioeconomic_data
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 1 rows affected.
# [(78,)]

# %%
# %%sql
# SELECT COUNT(*), community_area_name, hardship_index
# FROM chicago_socioeconomic_data
# WHERE LOWER(community_area_name) LIKE '%chicago%' AND hardship_index > 50
# GROUP BY community_area_name, hardship_index;
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 2 rows affected.
# [(1, 'Chicago Lawn', 80.0), (1, 'South Chicago', 75.0)]

# %%
# %sql SELECT count(*) FROM chicago_socioeconomic_data WHERE hardship_index > 50.0
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 1 rows affected.
# [(38,)]

# %%
# %sql SELECT MAX(hardship_index) FROM chicago_socioeconomic_data
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 1 rows affected.
# [(98.0,)]

# %%
# %%sql
# SELECT community_area_name,hardship_index  FROM chicago_socioeconomic_data WHERE hardship_index = (SELECT MAX(hardship_index) FROM chicago_socioeconomic_data)
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 1 rows affected.
# [('Riverdale', 98.0)]

# %%
# %%sql
# SELECT community_area_name, per_capita_income_ FROM chicago_socioeconomic_data WHERE per_capita_income_>60000
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 4 rows affected.
# [('Lake View', 60058),
#  ('Lincoln Park', 71551),
#  ('Near North Side', 88669),
#  ('Loop', 65526)]

# %%
# %%sql
# SELECT * FROM chicago_socioeconomic_data ORDER BY per_capita_income_ DESC NULLS LAST LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 10 rows affected.
# [(8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (32.0, 'Loop', 1.5, 14.7, 5.7, 3.1, 13.5, 65526, 3.0),
#  (6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (33.0, 'Near South Side', 1.3, 13.8, 4.9, 7.4, 21.8, 59077, 7.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (28.0, 'Near West Side', 3.8, 20.6, 10.7, 9.6, 22.2, 44689, 15.0),
#  (12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (24.0, 'West Town', 2.3, 14.7, 6.6, 12.9, 21.7, 43198, 10.0),
#  (9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0)]

# %%
# %sql SELECT * FROM chicago_socioeconomic_data ORDER BY per_capita_income_ ASC FETCH FIRST 5 ROWS ONLY
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 5 rows affected.
# [(54.0, 'Riverdale', 5.8, 56.5, 34.6, 27.5, 51.5, 8201, 98.0),
#  (30.0, 'South Lawndale', 15.2, 30.7, 15.8, 54.8, 33.8, 10402, 96.0),
#  (37.0, 'Fuller Park', 3.2, 51.2, 33.9, 26.6, 44.9, 10432, 97.0),
#  (26.0, 'West Garfield Park', 9.4, 41.7, 25.8, 24.5, 43.6, 10934, 92.0),
#  (67.0, 'West Englewood', 4.8, 34.4, 35.9, 26.3, 40.7, 11317, 89.0)]

# %%
# %%sql
# SELECT REPLACE(community_area_name,' ','_') as "community_area_name_without_space" FROM chicago_socioeconomic_data
# ORDER BY percent_of_housing_crowded
# FETCH FIRST 5 ROWS ONLY
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 5 rows affected.
# [('North_Center',),
#  ('Lincoln_Park',),
#  ('Morgan_Park',),
#  ('Beverly',),
#  ('Mount_Greenwood',)]

# %%
query = %sql SELECT per_capita_income_, hardship_index FROM chicago_socioeconomic_data
df = query.DataFrame()
# %matplotlib inline
# uncomment the following line if you get an module error saying seaborn not found
# !pip install seaborn
import seaborn

plot = seaborn.scatterplot(x='per_capita_income_',y='hardship_index', data=df)
# Out:
#  * postgresql://postgres:***@localhost:5432/INSTRUCTOR
# 78 rows affected.

# %% [markdown]
# ### Queries which can not be done due to not having tables

# %%
"Which Schools have Average Student Attendance lower than 70%?"
#%%sql 
#SELECT SCHOOL_ID, NAME_OF_SCHOOL, Average_Student_Attendance FROM SCHOOLS WHERE DECIMAL(REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
#ORDER BY Average_Student_Attendance DESC

"Get the total College Enrollment for each Community Area"
#%sql SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS SUM_ENROLLMENT FROM SCHOOLS group by Community_Area_Name ORDER BY SUM_ENROLLMENT DESC

"Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order"
#%sql SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS SUM_ENROLLMENT FROM SCHOOLS group by Community_Area_Name ORDER BY SUM_ENROLLMENT ASC LIMIT 5

"List 5 schools with lowest safety score."
#%sql SELECT NAME_OF_SCHOOL, SAFETY_SCORE FROM SCHOOLS ORDER BY SAFETY_SCORE ASC LIMIT 5

"Get the hardship index for the community area which has College Enrollment of 4368"
#%sql SELECT hardship_index FROM CHICAGO_SOCIOECONOMIC_DATA CD, SCHOOLS SH \
#WHERE CD.ca = SH.community_area_number \
#AND COLLEGE_ENROLLMENT = 4368

"Get the hardship index for the community area which has the school with the  highest enrollment."
#%sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
#where ca in \
#( select community_area_number from schools order by college_enrollment desc limit 1 )
